# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd3cb24e1-2caa-4f06-a3fc-3a5763d78a6e',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

df=pd.json_normalize(data['data'])

df.head(2)
df['timestamp']=pd.to_datetime('now')

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd3cb24e1-2caa-4f06-a3fc-3a5763d78a6e',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
  
df2=pd.json_normalize(data['data'])

df2['timestamp']=pd.to_datetime('now')
df = pd.concat([df, df2], ignore_index=True)

# %%
import os
import time

for i in range(333):
    api_runner()
    print('API COmpleted')
    time.sleep(5)
exit()
# Out:
# API COmpleted
# API COmpleted
# API COmpleted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 7
#       5     api_runner()
#       6     print('API COmpleted')
# ----> 7     time.sleep(5)
#       8 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             12279
# 1    1027      Ethereum    ETH      ethereum             10432
# 2      52           XRP    XRP           xrp              1672
# 3     825   Tether USDt   USDT        tether            140546
# 4    1839           BNB    BNB           bnb              2659
# 5    5426        Solana    SOL        solana               967
# 6    3408          USDC   USDC      usd-coin             30324
# 7      74      Dogecoin   DOGE      dogecoin              1270
# 8    1958          TRON    TRX          tron              1212
# 9    2010       Cardano    ADA       cardano              1560
# 10    512       Stellar    XLM       stellar               737
# 11  32196   Hyperliquid   HYPE   hyperliquid               124
# 12  20947           Sui    SUI           sui               739
# 13   1975     Chainlink   LINK     chainlink              2057
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash              1046
# 15      1       Bitcoin    BTC       bitcoin             12279
# 16   1027      Ethereum    ETH      ethereum             10432
# 17     52           XRP    XRP           xrp              1672
# 18    825   Tether USDt   USDT        tether            140547
# 19   1839           BNB    BNB           bnb              2659
# 20   5426        Solana    SOL        solana               967
# 21   3408          USDC   USDC      usd-coin             30324
# 22     74      Dogecoin   DOGE      dogecoin              1270
# 23   1958          TRON    TRX          tron              1212
# 24   2010       Cardano    ADA       cardano              1560
# 25    512       Stellar    XLM       stellar               737
# 26  32196   Hyperliquid   HYPE   hyperliquid               124
# 27  20947           Sui    SUI           sui               739
# 28   1975     Chainlink   LINK     chainlink              2057
# 29   1831  Bitcoin Cash    BCH  bitcoin-cash              1046
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2013-08-04T00:00:00.000Z
# 3   2015-02-25T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2014-08-05T00:00:00.000Z
# 11  2024-07-15T10:14:50.000Z
# 12  2022-07-12T08:03:11.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2013-08-04T00:00:00.000Z
# 18  2015-02-25T00:00:00.000Z
# 19  2017-07-25T00:00:00.000Z
# 20  2020-04-10T00:00:00.000Z
# 21  2018-10-08T00:00:00.000Z
# 22  2013-12-15T00:00:00.000Z
# 23  2017-09-13T00:00:00.000Z
# 24  2017-10-01T00:00:00.000Z
# 25  2014-08-05T00:00:00.000Z
# 26  2024-07-15T10:14:50.000Z
# 27  2022-07-12T08:03:11.000Z
# 28  2017-09-20T00:00:00.000Z
# 29  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 3   [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# 5   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10  [medium-of-exchange, enterprise-solutions, dec...  5.000181e+10
# 11  [decentralized-exchange-dex-token, defi, deriv...  1.000000e+09
# 12  [binance-launchpool, coinbase-ventures-portfol...  1.000000e+10
# 13  [platform, defi, oracles, smart-contracts, eth...           NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 15  [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 16  [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 17  [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 18  [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 19  [marketplace, centralized-exchange, payments, ...           NaN
# 20  [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 21  [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 22  [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 23  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 24  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 25  [medium-of-exchange, enterprise-solutions, dec...  5.000181e+10
# 26  [decentralized-exchange-dex-token, defi, deriv...  1.000000e+09
# 27  [binance-launchpool, coinbase-ventures-portfol...  1.000000e+10
# 28  [platform, defi, oracles, smart-contracts, eth...           NaN
# 29  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.990342e+07  1.990342e+07  ...                         60.1556
# 1         1.207092e+08  1.207092e+08  ...                         12.1623
# 2         5.930839e+10  9.998588e+10  ...                          5.0593
# 3         1.643420e+11  1.677832e+11  ...                          4.2472
# 4         1.392881e+08  1.392881e+08  ...                          2.8205
# 5         5.391322e+08  6.069007e+08  ...                          2.4245
# 6         6.474977e+10  6.474977e+10  ...                          1.6727
# 7         1.504260e+11  1.504260e+11  ...                          0.8640
# 8         9.470122e+10  9.470125e+10  ...                          0.8246
# 9         3.542733e+10  4.499097e+10  ...                          0.7210
# 10        3.126318e+10  5.000179e+10  ...                          0.3643
# 11        3.339282e+08  9.999939e+08  ...                          0.3522
# 12        3.511924e+09  1.000000e+10  ...                          0.3413
# 13        6.781000e+08  1.000000e+09  ...                          0.3215
# 14        1.990833e+07  1.990833e+07  ...                          0.2984
# 15        1.990342e+07  1.990342e+07  ...                         60.1569
# 16        1.207092e+08  1.207092e+08  ...                         12.1419
# 17        5.930839e+10  9.998588e+10  ...                          5.0508
# 18        1.643420e+11  1.677832e+11  ...                          4.2526
# 19        1.392881e+08  1.392881e+08  ...                          2.8208
# 20        5.391322e+08  6.069007e+08  ...                          2.4266
# 21        6.474324e+10  6.474324e+10  ...                          1.6746
# 22        1.504263e+11  1.504263e+11  ...                          0.8600
# 23        9.470128e+10  9.470127e+10  ...                          0.8261
# 24        3.542733e+10  4.499097e+10  ...                          0.7199
# 25        3.126318e+10  5.000179e+10  ...                          0.3644
# 26        3.339282e+08  9.999939e+08  ...                          0.3515
# 27        3.511924e+09  1.000000e+10  ...                          0.3403
# 28        6.781000e+08  1.000000e+09  ...                          0.3226
# 29        1.990834e+07  1.990834e+07  ...                          0.2968
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         2.456637e+12           None
# 1                         4.707488e+11           None
# 2                         3.301804e+11           None
# 3                         1.678225e+11           None
# 4                         1.091698e+11           None
# 5                         1.056366e+11           None
# 6                         6.473738e+10           None
# 7                         3.343968e+10           None
# 8                         3.191819e+10           None
# 9                         3.544672e+10           None
# 10                        2.255390e+10           None
# 11                        4.081844e+10           None
# 12                        3.762031e+10           None
# 13                        1.834999e+10           None
# 14                        1.218486e+10           None
# 15                        2.453947e+12           None
# 16                        4.694362e+11           None
# 17                        3.292567e+11           None
# 18                        1.678453e+11           None
# 19                        1.090602e+11           None
# 20                        1.056121e+11           None
# 21                        6.473961e+10           None
# 22                        3.325065e+10           None
# 23                        3.193960e+10           None
# 24                        3.535465e+10           None
# 25                        2.253029e+10           None
# 26                        4.069199e+10           None
# 27                        3.746712e+10           None
# 28                        1.839360e+10           None
# 29                        1.210418e+10           None
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2025-08-08T01:29:00.000Z          NaN           NaN             NaN
# 1   2025-08-08T01:30:00.000Z          NaN           NaN             NaN
# 2   2025-08-08T01:30:00.000Z          NaN           NaN             NaN
# 3   2025-08-08T01:29:00.000Z       1027.0      Ethereum             ETH
# 4   2025-08-08T01:29:00.000Z          NaN           NaN             NaN
# 5   2025-08-08T01:29:00.000Z          NaN           NaN             NaN
# 6   2025-08-08T01:29:00.000Z       1027.0      Ethereum             ETH
# 7   2025-08-08T01:29:00.000Z          NaN           NaN             NaN
# 8   2025-08-08T01:30:00.000Z          NaN           NaN             NaN
# 9   2025-08-08T01:30:00.000Z          NaN           NaN             NaN
# 10  2025-08-08T01:30:00.000Z          NaN           NaN             NaN
# 11  2025-08-08T01:29:00.000Z      32196.0   Hyperliquid            HYPE
# 12  2025-08-08T01:29:00.000Z          NaN           NaN             NaN
# 13  2025-08-08T01:29:00.000Z       1027.0      Ethereum             ETH
# 14  2025-08-08T01:30:00.000Z          NaN           NaN             NaN
# 15  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
# 16  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
# 17  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
# 18  2025-08-08T01:45:00.000Z       1027.0      Ethereum             ETH
# 19  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
# 20  2025-08-08T01:45:00.000Z          NaN           NaN             NaN
# 21  2025-08-08T01:45:00.000Z       1027.0      Ethereum             ETH
# 22  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
# 23  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
# 24  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
# 25  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
# 26  2025-08-08T01:46:00.000Z      32196.0   Hyperliquid            HYPE
# 27  2025-08-08T01:45:00.000Z          NaN           NaN             NaN
# 28  2025-08-08T01:45:00.000Z       1027.0      Ethereum             ETH
# 29  2025-08-08T01:46:00.000Z          NaN           NaN             NaN
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2             NaN                                         NaN
# 3        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 4             NaN                                         NaN
# 5             NaN                                         NaN
# 6        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
# 10            NaN                                         NaN
# 11    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 12            NaN                                         NaN
# 13       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14            NaN                                         NaN
# 15            NaN                                         NaN
# 16            NaN                                         NaN
# 17            NaN                                         NaN
# 18       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 19            NaN                                         NaN
# 20            NaN                                         NaN
# 21       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22            NaN                                         NaN
# 23            NaN                                         NaN
# 24            NaN                                         NaN
# 25            NaN                                         NaN
# 26    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 27            NaN                                         NaN
# 28       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 29            NaN                                         NaN
#
#                     timestamp
# 0  2025-08-08 07:01:40.847186
# 1  2025-08-08 07:01:40.847186
# 2  2025-08-08 07:01:40.847186
# 3  2025-08-08 07:01:40.847186
# 4  2025-08-08 07:01:40.847186
# 5  2025-08-08 07:01:40.847186
# 6  2025-08-08 07:01:40.847186
# 7  2025-08-08 07:01:40.847186
# 8  2025-08-08 07:01:40.847186
# 9  2025-08-08 07:01:40.847186
# 10 2025-08-08 07:01:40.847186
# 11 2025-08-08 07:01:40.847186
# 12 2025-08-08 07:01:40.847186
# 13 2025-08-08 07:01:40.847186
# 14 2025-08-08 07:01:40.847186
# 15 2025-08-08 07:16:55.610869
# 16 2025-08-08 07:16:55.610869
# 17 2025-08-08 07:16:55.610869
# 18 2025-08-08 07:16:55.610869
# 19 2025-08-08 07:16:55.610869
# 20 2025-08-08 07:16:55.610869
# 21 2025-08-08 07:16:55.610869
# 22 2025-08-08 07:16:55.610869
# 23 2025-08-08 07:16:55.610869
# 24 2025-08-08 07:16:55.610869
# 25 2025-08-08 07:16:55.610869
# 26 2025-08-08 07:16:55.610869
# 27 2025-08-08 07:16:55.610869
# 28 2025-08-08 07:16:55.610869
# 29 2025-08-08 07:16:55.610869
#
# [30 rows x 37 columns]
